# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('menu.csv')
df.head(5)
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
#kategoru mana yang memiliki rata-rata gula yang paling tinggi?
df.groupby('Category')['Sugars'].mean().sort_values().plot(kind='barh')
# Out:
# <Axes: ylabel='Category'>

# %%
#manakah menu yang paling banyak diminati?
df['Category'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#item manakah yang memiliki protein paling tinggi?
df.groupby(['Category','Item'])['Protein'].max().sort_values(ascending=False).head(5)
# Out:
# Category        Item
# Chicken & Fish  Chicken McNuggets (40 piece)                87
# Beef & Pork     Double Quarter Pounder with Cheese          48
# Chicken & Fish  Chicken McNuggets (20 piece)                44
#                 Premium Grilled Chicken Club Sandwich       40
#                 Bacon Clubhouse Grilled Chicken Sandwich    40
# Name: Protein, dtype: int64

# %%
#item manakah yang memiliki sugars paling rendah?
df.groupby(['Category','Item'])['Sugars'].min().sort_values(ascending=True).head(5)
# Out:
# Category        Item
# Snacks & Sides  Small French Fries        0
# Beverages       Diet Dr Pepper (Large)    0
#                 Diet Dr Pepper (Child)    0
#                 Diet Coke (Small)         0
#                 Diet Coke (Medium)        0
# Name: Sugars, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Total Fat', y='Cholesterol')
plt.title('Relasi Total Fat vs Cholesterol')
plt.xlabel('Total Fat (g)')
plt.ylabel('Cholesterol (mg)')
plt.grid(True)
plt.show()

correlation = df['Total Fat'].corr(df['Cholesterol'])
print(f'Korelasi antara Total Fat dan Cholesterol: {correlation:.2f}')
# Out:
# Korelasi antara Total Fat dan Cholesterol: 0.68

# %%
df[df['Category']== 'Salads']['Total Fat'].max()
# Out:
# np.float64(22.0)
